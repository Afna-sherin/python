# %%
#sort dictionary ascending or decending order
roll=input("enter roll(space seperated):").split()
name=input("enter name(space seperated):").split()
mydict=dict(zip(roll,name))
print("ascending order:",dict(sorted(mydict.items())))
print("descending order:",dict(sorted(mydict.items(),reverse=True)))
# Out:
# enter roll(space seperated): 1 2 3 5 4
# enter name(space seperated): afna roohi amrutha dilna athira
# ascending order: {'1': 'afna', '2': 'roohi', '3': 'amrutha', '4': 'athira', '5': 'dilna'}
# descending order: {'5': 'dilna', '4': 'athira', '3': 'amrutha', '2': 'roohi', '1': 'afna'}

# %%
dict1=dict(zip(input("enter 3 roll number:").split(),input("enter 3 names:").split()))
dict2=dict(zip(input("enter 2 roll number:").split(),input("enter 2 names:").split()))
print("dictionary1=",dict1)
print("dictionary2=",dict2)
dic1.update(dic2)
print("merged dictionary:",dic1)
