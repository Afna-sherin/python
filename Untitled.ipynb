# %%
name=input("enter your name:")
print("Hello,afna")
print(type(name))
# Out:
# enter your name:afna
# Hello,afna
# <class 'str'>

# %%
age=input("enter your age:")
print("Hello",age)
print(type(age))
# Out:
# enter your age:21
# Hello 21
# <class 'str'>

# %%
n1=int(input("enter first number"))
n2=int(input("enter second number"))
sum=n1+n2
print("sum=",sum)
# Out:
# enter first number3
# enter second number4
# sum= 7

# %%
import math
n=int(input("enter a number"))
result=math.sqrt(n)
print(result)
# Out:
# enter a number2
# 1.4142135623730951

# %%
import math
n=int(input("enter a number"))
result=math.sqrt(n)
print(round(result,2))
# Out:
# enter a number5
# 2.24
