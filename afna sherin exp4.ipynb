# %%
#list 
colors=input("enter the colors names:")
colors=colors.split(",")
print("enter the colors names:blue,red,orange")
print("first color:",colors[0])
print("last color:",colors[-1])
# Out:
# enter the colors names: blue,red,orange
# enter the colors names:blue,red,orange
# first color: blue
# last color: orange

# %%
#file
filename=input("enter filename:")
extension=filename.split(".")
print("enter file name:hello.py")
print("extension:",extension[-1])
# Out:
# enter filename: hello.py
# enter file name:hello.py
# extension: py

# %%
#sum 
numbers=input("enter the numbers:")
numbers=numbers.split(",")
numbers=list(map(int,numbers))
print("list:",numbers)
print("sum:",sum(numbers))
# Out:
# enter the numbers: 10,20,30
# list: [10, 20, 30]
# sum: 60
