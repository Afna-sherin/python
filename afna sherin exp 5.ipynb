# %%
#to get 3rd element and last 3rd elememt
n=input("enter the numbers:")
print("3rd element:",t[2])
print("3rd element from last:",t[-3])
# Out:
# enter the numbers: 10,20,30,40,50,60
# 3rd element: 30
# 3rd element from last: 40

# %%
#average of all items
numbers=input("enter the numbers:")
tuples=tuple(map(int,numbers.split(",")))
print("tuple:",tuples)
print("average:",sum(tuples)/len(tuples))
# Out:
# enter the numbers: 1,2,3,4
# tuple: (1, 2, 3, 4)
# average: 2.5
